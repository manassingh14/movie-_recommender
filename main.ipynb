# %%
import pandas as pd
df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
def create_textual_representation(row):
    textual_rep = f"""
        Type: {row['type']},
        Title:{row['title']},
        Cast:{row['cast']},
        Released:{row['release_year']},
        Genres: {row['listed_in']},
        Description: {row["description"]}
    """

    return textual_rep

# %%
df["textual_representation"] = df.apply(create_textual_representation  , axis=1)
print(df["textual_representation"].values[0])
# Out:
#         Type: Movie,
#         Title:Dick Johnson Is Dead,
#         Cast:nan,
#         Released:2020,
#         Genres: Documentaries,
#         Description: As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.

# %%
import faiss , requests , numpy as np

# dim= 4096
dim = 768
index = faiss.IndexFlatL2(dim)

X = np.zeros((len(df['textual_representation']), dim) , dtype='float32')

# %%
import google.generativeai as genai
GOOGLE_API_KEY = "AIzaSyDjEhm7Cz4zMrlz292c6pUJEAUw-Geimh0"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
result = genai.embed_content(
model="models/text-embedding-004",
content="What is the meaning of lraife?",
)
print(result)
# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED]')
# Out:
# {'embedding': [-0.038607907, 0.03186696, -0.02252485, 0.0013677803, -0.03864885, -0.0003472834, -0.0113452785, -0.0017598362, 0.009115536, 0.07618664, 0.027679637, -0.0025854053, 0.017855782, -0.0024999115, 0.016124772, -0.07948628, -0.0074879755, 0.026618455, -0.07165967, 0.00085567, 0.021923201, -0.026841689, 0.06681147, -0.037225846, -0.0056066406, 0.026517613, 0.036887325, -0.017786495, -0.0041898517, -0.04247489, 0.058449045, -0.00022650886, 0.06176812, -0.0054746876, 0.03194143, -0.0036781973, -0.0044066035, 0.034319267, 0.005817541, -0.019543137, -0.10875422, 0.025742888, -0.012242479, -0.009896149, 0.007808301, -0.03801328, -0.010193564, 0.033065315, -0.0034906296, 0.0466641, -0.021714488, -0.043569747, -0.011499229, 0.09484156, -0.047007233, -0.038539693, -0.035416946, 0.05023376, 0.005391096, 0.03058081, -0.037673466, -0.014429447, -0.03388487, -0.023452325, 0.032176808, 0.011185485, -0.031897012, -0.009038092, -0.0015581737, 0.01963459, -0.030893313, -0.015864672, -0.05632
# ...

# %%
# for i , representation in enumerate(df['textual_representation']):
#     if i%200 == 0:
#         print(f"Processed {i} instances")
    
#     res = genai.embed_content(
#             model="models/text-embedding-004",
#             content=representation,
#         )
#     X[i] = np.array(res['embedding'])
#     # print(res['embedding'])

# index.add(X)

# %%
# faiss.write_index(index , 'index')
index = faiss.read_index('index')
index
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x00000213CA4EB8D0> >

# %%
df[df.title.str.contains('Avengers')]
# Out:
#      show_id     type                                            title  \
# 713     s714  TV Show                       Avengers Climate Conundrum
# 5340   s5341    Movie  LEGO Marvel Super Heroes: Avengers Reassembled!
# 6200   s6201    Movie                           Avengers: Infinity War
#
#                       director  \
# 713                        NaN
# 5340             Rob Silvestri
# 6200  Anthony Russo, Joe Russo
#
#                                                    cast        country  \
# 713   Giles Panton, Michael Daingerfield, Bill Newto...  United States
# 5340  Laura Bailey, Troy Baker, Eric Bauza, Ben Disk...  United States
# 6200  Robert Downey Jr., Josh Brolin, Mark Ruffalo, ...  United States
#
#              date_added  release_year rating  duration  \
# 713       June 15, 2021          2020  TV-Y7  1 Season
# 5340     August 6, 2017          2015  TV-Y7    22 min
# 6200  December 25, 2018          2018  PG-13   150 min
#
# ...

# %%
df[df.title.str.contains('Shutter')]
# Out:
#      show_id   type           title                                  director  \
# 1358   s1359  Movie  Shutter Island                           Martin Scorsese
# 8013   s8014  Movie         Shutter  Banjong Pisanthanakun, Parkpoom Wongpoom
#
#                                                    cast        country  \
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...  United States
# 8013  Ananda Everingham, Natthaweeranuch Thongmee, A...       Thailand
#
#              date_added  release_year rating duration  \
# 1358   February 1, 2021          2010      R  139 min
# 8013  September 5, 2018          2004  TV-MA   96 min
#
#                                 listed_in  \
# 1358                            Thrillers
# 8013  Horror Movies, International Movies
#
#                                             description  \
# 1358  A U.S. marshal's troubling visions compromise ...
# 8013  After killing a young girl in a hit-and-run ac...
#
# ...

# %%
fav_movie = df.iloc[6200]

# %%
rep = """
Type : movie,
Title : The Avengers,
Director : Joss Whedon,
Cast : Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth, Scarlett Johansson, Jeremy Renner, Tom Hiddleston, Samuel L. Jackson, Clark Gregg, Cobie Smulders, Stellan Skarsgård, Gwyneth Paltrow,
Released : 2012,
Genres: action, adventure, sci-fi, superhero

Description: "The Avengers" is a Marvel superhero film that brings together Iron Man, Captain America, Thor, the Hulk, Black Widow, and Hawkeye to form a team tasked with defending Earth from the threat posed by the villain Loki and his alien army. The movie is known for its thrilling action sequences, witty dialogue, and groundbreaking ensemble cast, as the superheroes must learn to work together to save the world.

"""

# %%
res = genai.embed_content(
            model="models/text-embedding-004",
            # content= fav_movie['textual_representation'],
            content= rep
        )

embedding = np.array([res["embedding"]] , dtype='float32')

# print(embedding)

# %%
D,I = index.search(embedding , 5)

# %%
best_matches = np.array(df["textual_representation"])[I.flatten()]
best_matches
# Out:
# array(['\n        Type: Movie,\n        Title:Avengers: Infinity War,\n        Cast:Robert Downey Jr., Josh Brolin, Mark Ruffalo, Tom Hiddleston, Chris Evans, Chris Hemsworth, Jeremy Renner, Chris Pratt, Elizabeth Olsen, Sebastian Stan, Benedict Cumberbatch, Paul Bettany, Cobie Smulders, Benedict Wong, Zoe Saldana, Karen Gillan, Vin Diesel, Dave Bautista, Bradley Cooper, Pom Klementieff, Scarlett Johansson, Benicio Del Toro, Anthony Mackie, Chadwick Boseman, Danai Gurira, Paul Rudd, Don Cheadle, Tom Holland,\n        Released:2018,\n        Genres: Action & Adventure, Sci-Fi & Fantasy,\n        Description: Superheroes amass to stop intergalactic sociopath Thanos from acquiring a full set of Infinity Stones and wiping out half of all life in the universe.\n    ',
# ...

# %%
for match in best_matches:
    print('Next Movie')
    print(match)
    print()
# Out:
# Next Movie
#
#         Type: Movie,
#         Title:Avengers: Infinity War,
#         Cast:Robert Downey Jr., Josh Brolin, Mark Ruffalo, Tom Hiddleston, Chris Evans, Chris Hemsworth, Jeremy Renner, Chris Pratt, Elizabeth Olsen, Sebastian Stan, Benedict Cumberbatch, Paul Bettany, Cobie Smulders, Benedict Wong, Zoe Saldana, Karen Gillan, Vin Diesel, Dave Bautista, Bradley Cooper, Pom Klementieff, Scarlett Johansson, Benicio Del Toro, Anthony Mackie, Chadwick Boseman, Danai Gurira, Paul Rudd, Don Cheadle, Tom Holland,
#         Released:2018,
#         Genres: Action & Adventure, Sci-Fi & Fantasy,
#         Description: Superheroes amass to stop intergalactic sociopath Thanos from acquiring a full set of Infinity Stones and wiping out half of all life in the universe.
#
#
# Next Movie
#
#         Type: Movie,
#         Title:Thor: Ragnarok,
# ...
